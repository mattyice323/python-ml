# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install --user pandas
# Out:
# ...
#   Using cached pandas-1.5.2-cp38-cp38-win_amd64.whl (11.0 MB)
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Python38\python.exe -m pip install --upgrade pip' command.

# %%
# View packages in the kernel
pip list
# Out:
# Package                  Version
# ------------------------ -----------
# -                        p
# -ip                      20.1.1
# aniso8601                8.0.0
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# asttokens                2.2.1
# attrs                    22.1.0
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# certifi                  2022.12.7
# cffi                     1.15.1
# chardet                  3.0.4
# charset-normalizer       2.1.1
# Click                    7.0
# colorama                 0.4.6
# comm                     0.1.2
# debugpy                  1.6.4
# decorator                5.1.1
# defusedxml               0.7.1
# distlib                  0.3.6
# entrypoints              0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# filelock                 3.8.2
# ...

# %%
import pandas as pd

df = pd.read_csv("melb_data.csv")
df.describe() # Use describe function to get overview of dataset 

# Count shows how many rows have values for this field
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Drop n/as with dropna method
df2 = df.dropna(axis=0)
df2.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6196.000000  6.196000e+03  6196.000000  6196.000000  6196.000000
# mean      2.931407  1.068828e+06     9.751097  3101.947708     2.902034
# std       0.971079  6.751564e+05     5.612065    86.421604     0.970055
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.200000e+05     5.900000  3044.000000     2.000000
# 50%       3.000000  8.800000e+05     9.000000  3081.000000     3.000000
# 75%       4.000000  1.325000e+06    12.400000  3147.000000     3.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  6196.000000  6196.000000   6196.000000   6196.000000  6196.000000
# mean      1.576340     1.573596    471.006940    141.568645  1964.081988
# std       0.711362     0.929947    897.449881     90.834824    38.105673
# ...

# %%
# Prediction target is the price

predict_value = df2.Price # Dot notation is case sensitive 
predict_value
# Out:
# 1        1035000.0
# 2        1465000.0
# 4        1600000.0
# 6        1876000.0
# 7        1636000.0
#            ...
# 12205     601000.0
# 12206    1050000.0
# 12207     385000.0
# 12209     560000.0
# 12212    2450000.0
# Name: Price, Length: 6196, dtype: float64

# %%
features = ['Rooms', 'Bedroom2', 'Bathroom', 'YearBuilt', 'Landsize']

feature_df = df2[features]
feature_df.head()
# Out:
#    Rooms  Bedroom2  Bathroom  YearBuilt  Landsize
# 1      2       2.0       1.0     1900.0     156.0
# 2      3       3.0       2.0     1900.0     134.0
# 4      4       3.0       1.0     2014.0     120.0
# 6      3       4.0       2.0     1910.0     245.0
# 7      2       2.0       1.0     1890.0     256.0

# %%
# !{sys.executable} -m pip install --user scikit-learn
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Python38\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.tree import DecisionTreeRegressor
